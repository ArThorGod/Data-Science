# %%
import pandas as pd
# força o pandas não omitir nenhuma coluna
pd.set_option('display.max_columns', 21)

file_path = '/content/drive/MyDrive/Unifeb/2021/Aulas/IA/algoritmos/datasets/'
file_name = 'kc_house_data.csv'

file = pd.read_csv(file_path + file_name)

file.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# excluindo features irrelevantes
# O parâmetro axis = 1 que significa irá excluir uma coluna e não uma linha
# O parâmetro inplace é usado para persistir a alteração na variável dataset
# em memória, sem ele, a alteração não seria efetivada no objeto dataset.
file.drop('id', axis = 1, inplace = True)
file.drop('date', axis = 1, inplace = True)
file.drop('zipcode', axis = 1, inplace = True)
file.drop('lat', axis = 1, inplace = True)
file.drop('long', axis = 1, inplace = True)

file.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# ...

# %%
# definindo variáveis preditoras e variável algo
# Ou variáveis Independentes X e dependente Y
y = file['price']
x = file.drop('price', axis = 1)

# %%
#from sklearn.model_selection import train_test_split
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 2)
from sklearn.model_selection import cross_val_score, KFold
kfold = KFold(n_splits=7)

# %%
from sklearn.linear_model import Ridge, LinearRegression
# Criação do modelo de Machine Learning
modelLinear = LinearRegression()
modelRidge = Ridge()
# Alimentando o modelo com os dados Independente 'Target' e Dependentes 'Target'
#modelLinear.fit(x_train, y_train)
#modelRidge.fit(x_train, y_train)

# Fazendo a validação cruzada dos modelos e os dados
# cross_val_score
# estimator: Modelo Instanciado
# x: Variáveis Independentes - Features
# y: Variável Dependente - Target
# cv: Tipo da Validação Cruzada
result_linear = cross_val_score(modelLinear, x, y, cv= kfold)
result_ridge = cross_val_score(modelRidge, x, y, cv= kfold)

print(result_linear)
print(result_ridge)
# Out:
# [0.66569838 0.63560315 0.64662858 0.65979218 0.6609905  0.65791637
#  0.60969255]
# [0.66552964 0.63559766 0.64663422 0.65976601 0.6610491  0.65806824
#  0.60970752]

# %%
# resultLinear = modelLinear.score(x_test, y_test)
# print(resultLinear)

# resultLinear = modelRidge.score(x_test, y_test)
#print(resultLinear)

print(result_linear.mean())
print(result_ridge.mean())
# Out:
# 0.6480459585322915
# 0.6480503418402558
